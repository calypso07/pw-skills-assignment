# %%
import pandas as pd

# %% [markdown]
# Q.1

# %% [markdown]
# read_csv: This function is used to read data from a CSV file into a Pandas DataFrame.
#
# head: This function is used to display the first few rows of a DataFrame.
#
# tail: This function is used to display the last few rows of a DataFrame.
#
# info: This function is used to display information about a DataFrame, such as the number of rows and columns, and data types of columns.
#
# describe: This function is used to generate descriptive statistics for a DataFrame, such as count, mean, standard deviation, and quartiles.

# %%
df = pd.read_csv('services.csv')

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %% [markdown]
# Q.2

# %%
df = pd.DataFrame({'A':[9,8,7,1],
                   'B':[6,5,3,2],
                   'C':[3,2,1,3]
                  })

# %%
df
# Out:
#    A  B  C
# 0  9  6  3
# 1  8  5  2
# 2  7  3  1
# 3  1  2  3

# %%
def reindexx(df):
    ino = pd.RangeIndex(start=1, step=2, stop=len(df)*2)
    df.index = ino
    return df

# %%
newdf = reindexx(df)
print(newdf)
# Out:
#    A  B  C
# 1  9  6  3
# 3  8  5  2
# 5  7  3  1
# 7  1  2  3

# %% [markdown]
# Q.3

# %%
df['values'] = [32,45,23,64]

# %%
print(df['values'][:3].sum())
# Out:
# 100
# /tmp/ipykernel_98/3949737096.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   print(df['values'][:3].sum())

# %% [markdown]
# Q.4

# %%
df['text'] = ['The club isnt the best place to find a lover So the bar is where I go Me and my friends at the table doing shots', 'We push and pull like a magnet doAlthough my heart is falling too',' And now my bedsheets smell like youEvery day discovering something brand new','One week in we let the story begin We re going out on our first date']

# %%
df
# Out:
#    A  B  C  values                                               text
# 1  9  6  3      32  The club isnt the best place to find a lover S...
# 3  8  5  2      45  We push and pull like a magnet doAlthough my h...
# 5  7  3  1      23   And now my bedsheets smell like youEvery day ...
# 7  1  2  3      64  One week in we let the story begin We re going...

# %%
df['word_count'] = df['text'].apply(lambda x: len(str(x).split()))

# %%
df
# Out:
#    A  B  C  values                                               text  \
# 1  9  6  3      32  The club isnt the best place to find a lover S...
# 3  8  5  2      45  We push and pull like a magnet doAlthough my h...
# 5  7  3  1      23   And now my bedsheets smell like youEvery day ...
# 7  1  2  3      64  One week in we let the story begin We re going...
#
#    word_count
# 1          26
# 3          13
# 5          12
# 7          16

# %% [markdown]
# Q.5

# %% [markdown]
# The DataFrame.size and DataFrame.shape methods in Pandas are used to get information about the dimensions of a DataFrame, but they have different meanings:
#
# DataFrame.size returns the total number of elements in the DataFrame. It is equivalent to the product of the number of rows and columns in the DataFrame. For example, if a DataFrame has 3 rows and 4 columns, DataFrame.size will return 12.
#
# DataFrame.shape returns a tuple with the number of rows and columns in the DataFrame. For example, if a DataFrame has 3 rows and 4 columns, DataFrame.shape will return (3, 4).
#
# In summary, DataFrame.size returns the total number of elements in the DataFrame, while DataFrame.shape returns a tuple with the number of rows and columns in the DataFrame.

# %% [markdown]
# Q.6

# %% [markdown]
# o read an Excel file in Pandas, we use the read_excel() function.

# %% [markdown]
# Q.7

# %%
df['email'] = ['abc@gmail.com','dfd@gmail.com','fsc@gmail.com','mdc@gmail.com',]

# %%
df
# Out:
#    A  B  C          email
# 0  9  6  3  abc@gmail.com
# 1  8  5  2  dfd@gmail.com
# 2  7  3  1  fsc@gmail.com
# 3  1  2  3  mdc@gmail.com

# %%
def extractusr(df):
    df['username'] = df['email'].str.split('@').str[0]
    return df

# %%
extractusr(df)
# Out:
#    A  B  C          email username
# 0  9  6  3  abc@gmail.com      abc
# 1  8  5  2  dfd@gmail.com      dfd
# 2  7  3  1  fsc@gmail.com      fsc
# 3  1  2  3  mdc@gmail.com      mdc

# %% [markdown]
# Q.8

# %%
df1 = pd.DataFrame({'a':[0,12,2,13,4],
                    'b':[3,8,16,2,9],
                    'c':[5,2,9,3,1],
                    'd':[1,7,4,5,2]})

# %%
df1
# Out:
#     a  b  c  d
# 0   0  3  5  1
# 1  12  8  2  7
# 2   2  6  9  4
# 3  13  2  3  5
# 4   4  9  1  2

# %%
df1[(df1['a']>5) & (df1['b']<10)]
# Out:
#     a  b  c  d
# 1  12  8  2  7
# 3  13  2  3  5
